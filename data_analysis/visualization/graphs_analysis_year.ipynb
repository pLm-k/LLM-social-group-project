# %%
import pandas as pd
import matplotlib.pyplot as plt
file_path = 'path/to/data_analysis' #------------------change path to data_analysis dir here-------------!

year = '2008'

data = pd.read_csv(file_path+'/data_analysis/results/results_'+year+'.csv', sep='\t')

months = [s.split('-')[1] for s in data['year-month']]

# %%
# Plotting a bar graph
plt.bar(months, data['num_comments'])

# Adding labels and title
plt.xlabel('month')
plt.ylabel('num_comments')
plt.title('num_comments per month')

# Display the plot
plt.show()

# %%
# Plotting a bar graph
plt.bar(months, data['num_sentences'])

# Adding labels and title
plt.xlabel('month')
plt.ylabel('num_sentences')
plt.title('num_sentences per month')

# Display the plot
plt.show()

# %%
# Plotting a bar graph
plt.bar(months, data['max_num_sentences'])

# Adding labels and title
plt.xlabel('month')
plt.ylabel('max_num_sentences')
plt.title('max_num_sentences per month')

# Display the plot
plt.show()

# %%
# Plotting a bar graph
plt.bar(months, data['avg_num_sentences'])

# Adding labels and title
plt.xlabel('month')
plt.ylabel('avg_num_sentences')
plt.title('avg_num_sentences per month')

# Display the plot
plt.show()

# %%
# Plotting a bar graph
plt.bar(months, data['num_words'])

# Adding labels and title
plt.xlabel('month')
plt.ylabel('num_words')
plt.title('num_words per month')

# Display the plot
plt.show()

# %%
# Plotting a bar graph
plt.bar(months, data['max_num_words'])

# Adding labels and title
plt.xlabel('month')
plt.ylabel('max_num_words')
plt.title('max_num_words per month')

# Display the plot
plt.show()

# %%
# Plotting a bar graph
plt.bar(months, data['avg_num_words'])

# Adding labels and title
plt.xlabel('month')
plt.ylabel('avg_num_words')
plt.title('avg_num_words per month')

# Display the plot
plt.show()

# %%
# Plotting a bar graph
plt.bar(months, data['avg_words_sentence'])

# Adding labels and title
plt.xlabel('month')
plt.ylabel('avg_words_sentence')
plt.title('avg_words_sentence per month')

# Display the plot
plt.show()
